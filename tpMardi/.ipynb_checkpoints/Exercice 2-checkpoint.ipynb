# %%
import numpy as np
import pandas as pd
import matplotlib as mp 
import seaborn as sb

# %%
df = pd.read_csv('./data/sales_predictions.csv')
sb.relplot(x='date',y='item_price',data=df)

# %%
"il y a beaucoup de donnée à traiter donc la graphe prend beaucoup de temps à être créer"
# Out:
# 'il y a beaucoup de donnée à traiter donc la graphe prend beaucoup de temps à être créer'

# %%
sb.relplot(x='date',y='item_price',data=df.sample(50))

# %%
nuage=sb.relplot(x='date',y='item_price',data=df.sample(50))
nuage.fig.set_figwidth(20)
nuage.fig.set_figheight(6)

# %%
df['date']=pd.to_datetime(df['date'])
nuage=sb.relplot(x='date',y='item_price',data=df.sample(50))
nuage.fig.set_figwidth(20)
nuage.fig.set_figheight(6)
